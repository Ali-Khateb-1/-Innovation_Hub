# %%
 import os

# المسار الأساسي لمشروع الذكاء الاصطناعي داخل WSL2
base_path = "/mnt/c/Users/ali/Desktop/intro-to-ml-tensorflow"

# عرض الهيكلية الأساسية
print("📂 هيكلية:", base_path)
print("----------------------------")
for item in os.listdir(base_path):
    print(item)

# عرض هيكلية مجلد المشروع الفرعي
project_path = os.path.join(base_path, "projects", "p2_image_classifier")
print("\n📂 هيكلية:", project_path)
print("----------------------------")
for item in os.listdir(project_path):
    print(item)
# Out:
# 📂 هيكلية: /mnt/c/Users/ali/Desktop/intro-to-ml-tensorflow
# ----------------------------
# .git
# .github
# CODEOWNERS
# compose.yaml
# Dockerfile
# lessons
# projects
# README.md
# requirements.txt
#
# 📂 هيكلية: /mnt/c/Users/ali/Desktop/intro-to-ml-tensorflow/projects/p2_image_classifier
# ----------------------------
# .ipynb_checkpoints
# assets
# label_map.json
# Project_Image_Classifier_Project - Copy.ipynb
# README.md
# test_images

# %%
import json

# فتح ملف تصنيفات الصور
label_map_path = "/mnt/c/Users/ali/Desktop/intro-to-ml-tensorflow/projects/p2_image_classifier/label_map.json"

with open(label_map_path, "r") as file:
    label_data = json.load(file)

print("📌 محتوى label_map.json:")
print(json.dumps(label_data, indent=4))
# Out:
# 📌 محتوى label_map.json:
# {
#     "0": "pink primrose",
#     "1": "hard-leaved pocket orchid",
#     "2": "canterbury bells",
#     "3": "sweet pea",
#     "4": "english marigold",
#     "5": "tiger lily",
#     "6": "moon orchid",
#     "7": "bird of paradise",
#     "8": "monkshood",
#     "9": "globe thistle",
#     "10": "snapdragon",
#     "11": "colt's foot",
#     "12": "king protea",
#     "13": "spear thistle",
#     "14": "yellow iris",
#     "15": "globe-flower",
#     "16": "purple coneflower",
#     "17": "peruvian lily",
#     "18": "balloon flower",
#     "19": "giant white arum lily",
#     "20": "fire lily",
#     "21": "pincushion flower",
#     "22": "fritillary",
#     "23": "red ginger",
#     "24": "grape hyacinth",
#     "25": "corn poppy",
#     "26": "prince of wales feathers",
#     "27": "stemless gentian",
#     "28": "artichoke",
#     "29": "sweet william",
#     "30": "carnation",
#     "31": "garden phlox",
#     "32": "love in the mist",
# ...

# %%
import os

test_images_path = "/mnt/c/Users/ali/Desktop/intro-to-ml-tensorflow/projects/p2_image_classifier/test_images"

# عرض أسماء الملفات داخل مجلد الصور
image_files = os.listdir(test_images_path)
print("📂 قائمة الصور المتاحة:")
print(image_files)
# Out:
# 📂 قائمة الصور المتاحة:
# ['cautleya_spicata.jpg', 'hard-leaved_pocket_orchid.jpg', 'orange_dahlia.jpg', 'wild_pansy.jpg']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# المسار الأساسي لمجلد الصور
test_images_path = "/mnt/c/Users/ali/Desktop/intro-to-ml-tensorflow/projects/p2_image_classifier/test_images"

# تحميل وعرض الصور
image_files = ['cautleya_spicata.jpg', 'hard-leaved_pocket_orchid.jpg', 'orange_dahlia.jpg', 'wild_pansy.jpg']

fig, axes = plt.subplots(1, 4, figsize=(15, 5))

for i, image_file in enumerate(image_files):
    img = mpimg.imread(os.path.join(test_images_path, image_file))
    axes[i].imshow(img)
    axes[i].axis('off')
    axes[i].set_title(image_file)

plt.show()

# %%
import os

# تحديد مسار المجلد
folder_path = "C:/Users/ali/Desktop/Innovation_Hub_New/Full_Stack_Framework"

# استعراض الملفات والمجلدات داخل الهيكلية
def list_directory_structure(path, indent=0):
    try:
        for item in os.listdir(path):
            item_path = os.path.join(path, item)
            if os.path.isdir(item_path):
                print("  " * indent + f"[Folder] {item}")
                list_directory_structure(item_path, indent + 1)
            else:
                print("  " * indent + f"- {item}")
    except Exception as e:
        print(f"Error accessing {path}: {e}")

# تنفيذ التحليل
list_directory_structure(folder_path)
# Out:
# Error accessing C:/Users/ali/Desktop/Innovation_Hub_New/Full_Stack_Framework: [Errno 2] No such file or directory: 'C:/Users/ali/Desktop/Innovation_Hub_New/Full_Stack_Framework'

# %%
import os

# تحديد مسار المجلد داخل WSL
folder_path = "/mnt/c/Users/ali/Desktop/Innovation_Hub_New/Full_Stack_Framework"

# استعراض الملفات والمجلدات داخل الهيكلية
def list_directory_structure(path, indent=0):
    try:
        for item in os.listdir(path):
            item_path = os.path.join(path, item)
            if os.path.isdir(item_path):
                print("  " * indent + f"[Folder] {item}")
                list_directory_structure(item_path, indent + 1)
            else:
                print("  " * indent + f"- {item}")
    except Exception as e:
        print(f"Error accessing {path}: {e}")

# تنفيذ التحليل
list_directory_structure(folder_path)
# Out:
# [Folder] .ipynb_checkpoints
#   - AI_Model_Training-checkpoint.ipynb
#   - Automation_Scripts-checkpoint.ipynb
#   - Data_Integration-checkpoint.ipynb
#   - Dev_Structure_Manager-checkpoint.ipynb
#   - Market_Expansion_Strategies-checkpoint.ipynb
#   - Sustainability_Metrics-checkpoint.ipynb
#   - Untitled-checkpoint.ipynb
#   - User_Behavior_Insights-checkpoint.ipynb
# - AI_Model_Training.ipynb
# - Automation_Scripts.ipynb
# [Folder] Core_System_Framework
# - Data_Integration.ipynb
# [Folder] Data_Processing_Engine
# [Folder] Deployment_Strategies
# - Dev_Structure_Manager.ipynb
# - Market_Expansion_Strategies.ipynb
# [Folder] Project_Growth_Framework
# - Sustainability_Metrics.ipynb
# - Untitled.ipynb
# - User_Behavior_Insights.ipynb
# [Folder] User_Interaction_Flow
